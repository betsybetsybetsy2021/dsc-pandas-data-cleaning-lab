# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df = pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df = heroes_df.drop(labels='Unnamed: 0', axis=1)

#print(heroes_df.columns.values)

heroes_df.head()

#1) pandas.read_csv(filepath_or_buffer, *, sep=_NoDefault.no_default, delimiter=None, header='infer', names=_NoDefault.no_default, 
#index_col=None, usecols=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, 
#skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, 
#parse_dates=None, infer_datetime_format=_NoDefault.no_default, keep_date_col=False, date_parser=_NoDefault.no_default, date_format=None, 
#dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal='.', lineterminator=None, 
#quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, encoding_errors='strict', dialect=None, 
#on_bad_lines='error', delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None, storage_options=None, 
#dtype_backend=_NoDefault.no_default)

#2) DataFrame.drop(labels=None, *, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == [
    "name",
    "Gender",
    "Eye color",
    "Race",
    "Hair color",
    "Height",
    "Publisher",
    "Skin color",
    "Alignment",
    "Weight",
]

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
When we run the shape function on heroes_df we get the shape as 734 x 10 which confirms what we asserted in the code block with the 
assertion functions.  There are indeed 10 column names and there are 734 rows.  Most of the columns have 734 non-null values, but the columns
Publisher and Weight both have null values.  
"""

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df = pd.read_csv('super_hero_powers.csv', index_col=0)

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == "3-D Man"

# The last column should be 'Zoom'
assert powers_df.columns[-1] == "Zoom"

# The first index should be 'Agility'
assert powers_df.index[0] == "Agility"

# The last index should be 'Omniscient'
assert powers_df.index[-1] == "Omniscient"

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(
    5, random_state=1
)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(
    5, random_state=1
)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
I believe that in most cases, dropping data is ill advised unless in cases of dealing with defunct services (like timing information for
a bus route that is no longer in operation so data would be all null). In this case we do not want to lose any of the character names, so
dropping row or columns is not advised.  Replacing with incorrect data is also a no go.  In this case, replacing the null value with 
something like "unknown" seems logical as relaying that the information was not recorded or processed properly may be important for data 
users, especially comic book lovers who will know when data is missing or incorrect!
"""

# %% [markdown]
# Now, implement the strategy to drop rows with missing values using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
# The instructions above say to drop info but I don't want to, so I am implementing the solution I as asked to provide.
heroes_df['Publisher'] = heroes_df['Publisher'].replace(np.nan, 'Unknown')

#DataFrame.replace(to_replace=None, value=_NoDefault.no_default, *, inplace=False, limit=None, regex=False, method=_NoDefault.no_default)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Unknown               15
# Image Comics          14
# George Lucas          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# ABC Studios            4
# IDW Publishing         4
# Shueisha               4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# Microsoft              1
# Titan Books            1
# Rebellion              1
# South Park             1
# J. K. Rowling          1
# Universal Studios      1
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
There are two variations of DC Comics and two variations of Marvel Comics.
"""

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
heroes_df['Publisher'] = heroes_df['Publisher'].replace('Marvel', 'Marvel Comics')
heroes_df['Publisher'] = heroes_df['Publisher'].str.strip()

#Series.str.strip(to_strip=None)
#heroes_df['Publisher'] = heroes_df['Publisher'].replace(np.nan, 'Unknown')

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Unknown               15
# George Lucas          14
# Image Comics          14
# HarperCollins          6
# Star Trek              6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# ABC Studios            4
# IDW Publishing         4
# Shueisha               4
# Wildstorm              3
# Sony Pictures          2
# Microsoft              1
# Titan Books            1
# Rebellion              1
# South Park             1
# J. K. Rowling          1
# Universal Studios      1
# Hanna-Barbera          1
# J. R. R. Tolkien       1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [734 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The First Column after the index in heroes_df includes the names of all of the superheroes which corresponds to the column names in
powers_df.  Math brain (linear algebra) says transpose. I plan to transpose powers_df and use the hero name as the index to join.
There are superhero names in heroes_df (734 names) that are not in powers_df (667 names); hopefully, all of the superheroes in powers_df 
will be in heroes_df.  So a left join to add the transposed version of powers_df should preserve all the data in heroes_df, but resulting in
null values for the "powers" data fields for superhero names that are not in heroes_df.
"""

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)
transposed_powers_df = powers_df.transpose()
transposed_powers_df.head()

heroes_and_powers_df = heroes_df.join(transposed_powers_df, on='name', how='left')

#DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a DataFrame with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you might need to
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [139], line 7
#       4 assert type(heroes_and_powers_df) == pd.DataFrame
#       6 # Confirms you have the right number of rows
# ----> 7 assert heroes_and_powers_df.shape[0] == 647
#       9 # Confirms you have the necessary columns
#      10 # (If you modified the value of powers_df along the way, you might need to
#      11 # modify this test. We are checking that all of the powers are present as
#      12 # columns.)
#      13 assert [power in heroes_and_powers_df.columns for power in powers_df.index]
#
# AssertionError:

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum(
    [heroes_and_powers_df[power_name] for power_name in powers_df.index]
)
heroes_and_powers_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 4     -99.0      Marvel Comics          -       bad   -99.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#     Reality Warping Odin Force Symbiote Costume Speed Force Phoenix Force  \
# 0             False      False            False       False         False
# 1             False      False            False       False         False
# 2             False      False            False       False         False
# 3             False      False            False       False         False
# 4             False      False            False       False         False
# ..              ...        ...              ...         ...           ...
# 729           False      False            False       False         False
# 730           False      False            False       False         False
# 731           False      False            False       False         False
# 732           False      False            False       False         False
# 733           False      False            False       False         False
#
#     Molecular Dissipation Vision - Cryo Omnipresent Omniscient Power Count
# 0                   False         False       False      False           7
# 1                   False         False       False      False          16
# 2                   False         False       False      False           1
# 3                   False         False       False      False           8
# 4                   False         False       False      False          14
# ..                    ...           ...         ...        ...         ...
# 729                 False         False       False      False           3
# 730                 False         False       False      False           6
# 731                 False         False       False      False          19
# 732                 False         False       False      False           8
# 733                 False         False       False      False           4
#
# [734 rows x 178 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"], y=heroes_and_powers_df["Power Count"], alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                  name Gender Eye color Race        Hair color  Height  \
# 251     Fallen One II   Male     black    -              Blue   -99.0
# 100     Black Goliath   Male         -    -                 -   -99.0
# 112       Blaquesmith      -     black    -           No Hair   -99.0
# 188  Crimson Crusader   Male      blue    -  Strawberry Blond   -99.0
# 325     Hiro Nakamura   Male         -    -                 -   -99.0
#
#          Publisher Skin color Alignment  Weight  ... Reality Warping  \
# 251  Marvel Comics          -       bad   -99.0  ...           False
# 100  Marvel Comics          -      good   -99.0  ...             NaN
# 112  Marvel Comics          -      good   -99.0  ...             NaN
# 188  Marvel Comics          -      good   -99.0  ...           False
# 325   NBC - Heroes          -      good   -99.0  ...           False
#
#     Odin Force Symbiote Costume Speed Force Phoenix Force  \
# 251      False            False       False         False
# 100        NaN              NaN         NaN           NaN
# 112        NaN              NaN         NaN           NaN
# 188      False            False       False         False
# 325      False            False       False         False
#
#     Molecular Dissipation Vision - Cryo Omnipresent Omniscient Power Count
# 251                 False         False       False      False          18
# 100                   NaN           NaN         NaN        NaN         NaN
# 112                   NaN           NaN         NaN        NaN         NaN
# 188                 False         False       False      False           4
# 325                 False         False       False      False           2
#
# [5 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight  ...  \
# 0     203.0      Marvel Comics          -      good   441.0  ...
# 1     191.0  Dark Horse Comics       blue      good    65.0  ...
# 2     185.0          DC Comics        red      good    90.0  ...
# 3     203.0      Marvel Comics          -       bad   441.0  ...
# 5     193.0      Marvel Comics          -       bad   122.0  ...
# ..      ...                ...        ...       ...     ...  ...
# 729   165.0      Marvel Comics          -      good    52.0  ...
# 730   304.8      Marvel Comics      white      good   -99.0  ...
# 731    66.0       George Lucas      green      good    17.0  ...
# 732   170.0          DC Comics          -      good    57.0  ...
# 733   185.0          DC Comics          -       bad    81.0  ...
#
#     Reality Warping Odin Force Symbiote Costume Speed Force Phoenix Force  \
# 0             False      False            False       False         False
# 1             False      False            False       False         False
# 2             False      False            False       False         False
# 3             False      False            False       False         False
# 5             False      False            False       False         False
# ..              ...        ...              ...         ...           ...
# 729           False      False            False       False         False
# 730           False      False            False       False         False
# 731           False      False            False       False         False
# 732           False      False            False       False         False
# 733           False      False            False       False         False
#
#     Molecular Dissipation Vision - Cryo Omnipresent Omniscient Power Count
# 0                   False         False       False      False           7
# 1                   False         False       False      False          16
# 2                   False         False       False      False           1
# 3                   False         False       False      False           8
# 5                   False         False       False      False          11
# ..                    ...           ...         ...        ...         ...
# 729                 False         False       False      False           3
# 730                 False         False       False      False           6
# 731                 False         False       False      False          19
# 732                 False         False       False      False           8
# 733                 False         False       False      False           4
#
# [517 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(x=question_2_df["Height"], y=question_2_df["Power Count"], alpha=0.3)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[
    (question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")
]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male",
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="#FF007F",
    label="Female",
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other",
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
# Your code here (create more cells as needed)
# I want to group by "Publisher" and then valuecount the power status (True/False), still trying to work out how.  Split-Apply-Combine

publishers = ['DC Comics', 'Marvel Comics']
powers_list = transposed_powers_df.columns.values # This is a numpy array
question_3_df = pd.DataFrame({'Superpower Name': powers_list})#,{'Marvel Comics':},{'DC Comics':})
question_3_df.head()

#function = [lambda x: heroes_and_powers_df[x].value_counts() for x in question_3_df['Superpower Name']] 

for x in powers_list:
    print(heroes_and_powers_df.groupby('Publisher')[x].value_counts())

#grouped = 

heroes_and_powers_df.groupby('Publisher')#[transposed_powers_df.columns.values]

#grouped.get_group('Marvel Comics')

    #heroes_and_powers_df.groupby('Publisher').apply(function)

#func = lambda x: x.size() / x.sum()
#data = frame.groupby('my_labels').apply(func)


#df['Code'] = df.apply(lambda x: generateCode())

#question_3_df.groupby("Publisher").agg(lambda x: x in powers_list)
                    # print(df.groupby(['id']).agg({'bool': 'sum'}))
# Out:
# Publisher          Agility
# ABC Studios        False        4
# DC Comics          False      125
#                    True        71
# Dark Horse Comics  False        9
#                    True         9
# George Lucas       True         9
#                    False        4
# Hanna-Barbera      True         1
# HarperCollins      False        3
# IDW Publishing     True         4
# Icon Comics        True         3
#                    False        1
# Image Comics       False       13
#                    True         1
# J. K. Rowling      True         1
# J. R. R. Tolkien   False        1
# Marvel Comics      False      215
#                    True       126
# Microsoft          True         1
# NBC - Heroes       False       18
# Rebellion          True         1
# Shueisha           True         4
# Sony Pictures      True         1
# South Park         False        1
# Star Trek          False        5
#                    True         1
# SyFy               False        5
# Team Epic TV       False        3
#                    True         2
# Titan Books        False        1
# Universal Studios  False        1
# Unknown            True         8
#                    False        5
# Wildstorm          False        2
#                    True         1
# Name: Agility, dtype: int64
# Publisher          Accelerated Healing
# ABC Studios        False                    3
#                    True                     1
# DC Comics          False                  145
#                    True                    51
# Dark Horse Comics  False                   10
#                    True                     8
# George Lucas       False                   10
#                    True                     3
# Hanna-Barbera      False                    1
# HarperCollins      False                    3
# IDW Publishing     True                     4
# Icon Comics        False                    4
# Image Comics       False                   11
#                    True                     3
# J. K. Rowling      True                     1
# J. R. R. Tolkien   True                     1
# Marvel Comics      False                  241
#                    True                   100
# Microsoft          True                     1
# NBC - Heroes       False                   16
#                    True                     2
# Rebellion          False                    1
# Shueisha           True                     3
#                    False                    1
# Sony Pictures      True                     1
# South Park         False                    1
# Star Trek          False                    6
# SyFy               False                    5
# Team Epic TV       False                    4
#                    True                     1
# Titan Books        False                    1
# Universal Studios  False                    1
# Unknown            False                   13
# Wildstorm          False                    2
#                    True                     1
# Name: Accelerated Healing, dtype: int64
# Publisher          Lantern Power Ring
# ABC Studios        False                   4
# DC Comics          False                 185
#                    True                   11
# Dark Horse Comics  False                  18
# George Lucas       False                  13
# Hanna-Barbera      False                   1
# HarperCollins      False                   3
# IDW Publishing     False                   4
# Icon Comics        False                   4
# Image Comics       False                  14
# J. K. Rowling      False                   1
# J. R. R. Tolkien   False                   1
# Marvel Comics      False                 341
# Microsoft          False                   1
# NBC - Heroes       False                  18
# Rebellion          False                   1
# Shueisha           False                   4
# Sony Pictures      False                   1
# South Park         False                   1
# Star Trek          False                   6
# SyFy               False                   5
# Team Epic TV       False                   5
# Titan Books        False                   1
# Universal Studios  False                   1
# Unknown            False                  13
# Wildstorm          False                   3
# Name: Lantern Power Ring, dtype: int64
# Publisher          Dimensional Awareness
# ABC Studios        False                      4
# DC Comics          False                    189
#                    True                       7
# Dark Horse Comics  False                     18
# George Lucas       False                     13
# Hanna-Barbera      False                      1
# HarperCollins      False                      3
# IDW Publishing     False                      4
# Icon Comics        False                      4
# Image Comics       False                     13
#                    True                       1
# J. K. Rowling      False                      1
# J. R. R. Tolkien   False                      1
# Marvel Comics      False                    325
#                    True                      16
# Microsoft          False                      1
# NBC - Heroes       False                     18
# Rebellion          False                      1
# Shueisha           False                      4
# Sony Pictures      False                      1
# South Park         False                      1
# Star Trek          False                      5
#                    True                       1
# SyFy               False                      5
# Team Epic TV       False                      5
# Titan Books        False                      1
# Universal Studios  False                      1
# Unknown            False                     13
# Wildstorm          False                      3
# Name: Dimensional Awareness, dtype: int64
# Publisher          Cold Resistance
# ABC Studios        False                4
# DC Comics          False              181
#                    True                15
# Dark Horse Comics  False               11
#                    True                 7
# George Lucas       False               13
# Hanna-Barbera      False                1
# HarperCollins      False                3
# IDW Publishing     False                4
# Icon Comics        False                4
# Image Comics       False               14
# J. K. Rowling      False                1
# J. R. R. Tolkien   False                1
# Marvel Comics      False              316
#                    True                25
# Microsoft          False                1
# NBC - Heroes       False               17
#                    True                 1
# Rebellion          False                1
# Shueisha           False                4
# Sony Pictures      False                1
# South Park         False                1
# Star Trek          False                5
#                    True                 1
# SyFy               False                5
# Team Epic TV       False                5
# Titan Books        False                1
# Universal Studios  False                1
# Unknown            False               13
# Wildstorm          False                3
# Name: Cold Resistance, dtype: int64
# Publisher          Durability
# ABC Studios        False           3
#                    True            1
# DC Comics          False         125
#                    True           71
# Dark Horse Comics  True           12
#                    False           6
# George Lucas       False           8
#                    True            5
# Hanna-Barbera      False           1
# HarperCollins      False           3
# IDW Publishing     False           4
# Icon Comics        False           3
#                    True            1
# Image Comics       False           8
#                    True            6
# J. K. Rowling      False           1
# J. R. R. Tolkien   False           1
# Marvel Comics      False         187
#                    True          154
# Microsoft          True            1
# NBC - Heroes       False          18
# Rebellion          False           1
# Shueisha           False           4
# Sony Pictures      True            1
# South Park         False           1
# Star Trek          False           5
#                    True            1
# SyFy               False           5
# Team Epic TV       False           5
# Titan Books        True            1
# Universal Studios  True            1
# Unknown            False           7
#                    True            6
# Wildstorm          False           2
#                    True            1
# Name: Durability, dtype: int64
# Publisher          Stealth
# ABC Studios        False        4
# DC Comics          False      148
#                    True        48
# Dark Horse Comics  True        10
#                    False        8
# George Lucas       True         8
#                    False        5
# Hanna-Barbera      False        1
# HarperCollins      False        3
# IDW Publishing     True         4
# Icon Comics        False        3
#                    True         1
# Image Comics       False       13
#                    True         1
# J. K. Rowling      True         1
# J. R. R. Tolkien   False        1
# Marvel Comics      False      294
#                    True        47
# Microsoft          False        1
# NBC - Heroes       False       18
# Rebellion          False        1
# Shueisha           False        3
#                    True         1
# Sony Pictures      False        1
# South Park         False        1
# Star Trek          False        3
#                    True         3
# SyFy               False        5
# Team Epic TV       False        5
# Titan Books        True         1
# Universal Studios  False        1
# Unknown            False        7
#                    True         6
# Wildstorm          False        2
#                    True         1
# Name: Stealth, dtype: int64
# Publisher          Energy Absorption
# ABC Studios        False                  4
# DC Comics          False                166
#                    True                  30
# Dark Horse Comics  False                 18
# George Lucas       False                 13
# Hanna-Barbera      True                   1
# HarperCollins      False                  3
# IDW Publishing     False                  4
# Icon Comics        False                  4
# Image Comics       False                 13
#                    True                   1
# J. K. Rowling      False                  1
# J. R. R. Tolkien   False                  1
# Marvel Comics      False                298
#                    True                  43
# Microsoft          False                  1
# NBC - Heroes       False                 18
# Rebellion          False                  1
# Shueisha           False                  4
# Sony Pictures      False                  1
# South Park         False                  1
# Star Trek          False                  6
# SyFy               False                  5
# Team Epic TV       False                  5
# Titan Books        False                  1
# Universal Studios  False                  1
# Unknown            False                 12
#                    True                   1
# Wildstorm          False                  2
#                    True                   1
# Name: Energy Absorption, dtype: int64
# Publisher          Flight
# ABC Studios        False       4
# DC Comics          False     110
#                    True       86
# Dark Horse Comics  False      15
#                    True        3
# George Lucas       False      12
#                    True        1
# Hanna-Barbera      True        1
# HarperCollins      True        2
#                    False       1
# IDW Publishing     False       4
# Icon Comics        False       4
# Image Comics       False      12
#                    True        2
# J. K. Rowling      False       1
# J. R. R. Tolkien   False       1
# Marvel Comics      False     230
#                    True      111
# Microsoft          False       1
# NBC - Heroes       False      17
#                    True        1
# Rebellion          False       1
# Shueisha           False       2
#                    True        2
# Sony Pictures      True        1
# South Park         True        1
# Star Trek          False       6
# SyFy               False       5
# Team Epic TV       False       5
# Titan Books        False       1
# Universal Studios  False       1
# Unknown            False      12
#                    True        1
# Wildstorm          False       3
# Name: Flight, dtype: int64
# Publisher          Danger Sense
# ABC Studios        False             4
# DC Comics          False           193
#                    True              3
# Dark Horse Comics  False            17
#                    True              1
# George Lucas       False             8
#                    True              5
# Hanna-Barbera      False             1
# HarperCollins      False             3
# IDW Publishing     False             4
# Icon Comics        False             4
# Image Comics       False            13
#                    True              1
# J. K. Rowling      False             1
# J. R. R. Tolkien   False             1
# Marvel Comics      False           321
#                    True             20
# Microsoft          False             1
# NBC - Heroes       False            18
# Rebellion          False             1
# Shueisha           False             2
#                    True              2
# Sony Pictures      False             1
# South Park         False             1
# Star Trek          False             6
# SyFy               False             5
# Team Epic TV       False             5
# Titan Books        False             1
# Universal Studios  False             1
# Unknown            False            12
#                    True              1
# Wildstorm          False             2
#                    True              1
# Name: Danger Sense, dtype: int64
# Publisher          Underwater breathing
# ABC Studios        False                     4
# DC Comics          False                   184
#                    True                     12
# Dark Horse Comics  False                    17
#                    True                      1
# George Lucas       False                    13
# Hanna-Barbera      False                     1
# HarperCollins      False                     3
# IDW Publishing     False                     4
# Icon Comics        False                     4
# Image Comics       False                    14
# J. K. Rowling      False                     1
# J. R. R. Tolkien   False                     1
# Marvel Comics      False                   332
#                    True                      9
# Microsoft          False                     1
# NBC - Heroes       False                    17
#                    True                      1
# Rebellion          False                     1
# Shueisha           False                     4
# Sony Pictures      False                     1
# South Park         False                     1
# Star Trek          False                     6
# SyFy               False                     5
# Team Epic TV       False                     5
# Titan Books        False                     1
# Universal Studios  False                     1
# Unknown            False                    13
# Wildstorm          False                     3
# Name: Underwater breathing, dtype: int64
# Publisher          Marksmanship
# ABC Studios        False             4
# DC Comics          False           152
#                    True             44
# Dark Horse Comics  False            13
#                    True              5
# George Lucas       True              8
#                    False             5
# Hanna-Barbera      False             1
# HarperCollins      False             3
# IDW Publishing     True              4
# Icon Comics        False             4
# Image Comics       False            14
# J. K. Rowling      False             1
# J. R. R. Tolkien   False             1
# Marvel Comics      False           294
#                    True             47
# Microsoft          True              1
# NBC - Heroes       False            18
# Rebellion          True              1
# Shueisha           True              3
#                    False             1
# Sony Pictures      False             1
# South Park         False             1
# Star Trek          False             4
#                    True              2
# SyFy               False             4
#                    True              1
# Team Epic TV       False             5
# Titan Books        True              1
# Universal Studios  False             1
# Unknown            False             8
#                    True              5
# Wildstorm          True              2
#                    False             1
# Name: Marksmanship, dtype: int64
# Publisher          Weapons Master
# ABC Studios        False               4
# DC Comics          False             156
#                    True               40
# Dark Horse Comics  False              11
#                    True                7
# George Lucas       True                8
#                    False               5
# Hanna-Barbera      False               1
# HarperCollins      False               3
# IDW Publishing     True                4
# Icon Comics        False               4
# Image Comics       False              13
#                    True                1
# J. K. Rowling      False               1
# J. R. R. Tolkien   True                1
# Marvel Comics      False             305
#                    True               36
# Microsoft          False               1
# NBC - Heroes       False              18
# Rebellion          True                1
# Shueisha           False               2
#                    True                2
# Sony Pictures      False               1
# South Park         False               1
# Star Trek          False               5
#                    True                1
# SyFy               False               5
# Team Epic TV       False               5
# Titan Books        True                1
# Universal Studios  False               1
# Unknown            False               9
#                    True                4
# Wildstorm          False               2
#                    True                1
# Name: Weapons Master, dtype: int64
# Publisher          Power Augmentation
# ABC Studios        False                   4
# DC Comics          False                 194
#                    True                    2
# Dark Horse Comics  False                  18
# George Lucas       False                  13
# Hanna-Barbera      False                   1
# HarperCollins      False                   3
# IDW Publishing     False                   4
# Icon Comics        False                   4
# Image Comics       False                  14
# J. K. Rowling      False                   1
# J. R. R. Tolkien   False                   1
# Marvel Comics      False                 336
#                    True                    5
# Microsoft          False                   1
# NBC - Heroes       False                  17
#                    True                    1
# Rebellion          False                   1
# Shueisha           False                   4
# Sony Pictures      False                   1
# South Park         False                   1
# Star Trek          False                   6
# SyFy               False                   5
# Team Epic TV       False                   5
# Titan Books        False                   1
# Universal Studios  False                   1
# Unknown            False                  13
# Wildstorm          False                   3
# Name: Power Augmentation, dtype: int64
# Publisher          Animal Attributes
# ABC Studios        False                  4
# DC Comics          False                188
#                    True                   8
# Dark Horse Comics  False                 18
# George Lucas       False                 13
# Hanna-Barbera      False                  1
# HarperCollins      False                  3
# IDW Publishing     False                  4
# Icon Comics        False                  4
# Image Comics       False                 13
#                    True                   1
# J. K. Rowling      False                  1
# J. R. R. Tolkien   False                  1
# Marvel Comics      False                324
#                    True                  17
# Microsoft          False                  1
# NBC - Heroes       False                 18
# Rebellion          False                  1
# Shueisha           False                  4
# Sony Pictures      False                  1
# South Park         False                  1
# Star Trek          False                  6
# SyFy               False                  5
# Team Epic TV       False                  5
# Titan Books        False                  1
# Universal Studios  False                  1
# Unknown            False                 13
# Wildstorm          False                  3
# Name: Animal Attributes, dtype: int64
# Publisher          Longevity
# ABC Studios        False          4
# DC Comics          False        163
#                    True          33
# Dark Horse Comics  False         10
#                    True           8
# George Lucas       False         12
#                    True           1
# Hanna-Barbera      True           1
# HarperCollins      False          3
# IDW Publishing     False          4
# Icon Comics        False          4
# Image Comics       False         12
#                    True           2
# J. K. Rowling      False          1
# J. R. R. Tolkien   True           1
# Marvel Comics      False        281
#                    True          60
# Microsoft          True           1
# NBC - Heroes       False         18
# Rebellion          False          1
# Shueisha           True           3
#                    False          1
# Sony Pictures      False          1
# South Park         False          1
# Star Trek          False          4
#                    True           2
# SyFy               False          5
# Team Epic TV       False          4
#                    True           1
# Titan Books        False          1
# Universal Studios  False          1
# Unknown            False         11
#                    True           2
# Wildstorm          False          2
#                    True           1
# Name: Longevity, dtype: int64
# Publisher          Intelligence
# ABC Studios        False             3
#                    True              1
# DC Comics          False           129
#                    True             67
# Dark Horse Comics  False            12
#                    True              6
# George Lucas       False             7
#                    True              6
# Hanna-Barbera      True              1
# HarperCollins      False             3
# IDW Publishing     False             4
# Icon Comics        False             3
#                    True              1
# Image Comics       False            12
#                    True              2
# J. K. Rowling      True              1
# J. R. R. Tolkien   True              1
# Marvel Comics      False           282
#                    True             59
# Microsoft          False             1
# NBC - Heroes       False            18
# Rebellion          False             1
# Shueisha           False             3
#                    True              1
# Sony Pictures      False             1
# South Park         False             1
# Star Trek          True              6
# SyFy               False             4
#                    True              1
# Team Epic TV       False             4
#                    True              1
# Titan Books        True              1
# Universal Studios  True              1
# Unknown            False            11
#                    True              2
# Wildstorm          False             3
# Name: Intelligence, dtype: int64
# Publisher          Super Strength
# ABC Studios        False               3
#                    True                1
# DC Comics          True              109
#                    False              87
# Dark Horse Comics  True               13
#                    False               5
# George Lucas       False              11
#                    True                2
# Hanna-Barbera      True                1
# HarperCollins      False               2
#                    True                1
# IDW Publishing     False               4
# Icon Comics        False               4
# Image Comics       True                9
#                    False               5
# J. K. Rowling      False               1
# J. R. R. Tolkien   True                1
# Marvel Comics      True              204
#                    False             137
# Microsoft          False               1
# NBC - Heroes       False              16
#                    True                2
# Rebellion          False               1
# Shueisha           True                4
# Sony Pictures      True                1
# South Park         False               1
# Star Trek          False               4
#                    True                2
# SyFy               False               4
#                    True                1
# Team Epic TV       True                3
#                    False               2
# Titan Books        False               1
# Universal Studios  True                1
# Unknown            False               8
#                    True                5
# Wildstorm          True                2
#                    False               1
# Name: Super Strength, dtype: int64
# Publisher          Cryokinesis
# ABC Studios        False            4
# DC Comics          False          189
#                    True             7
# Dark Horse Comics  False           18
# George Lucas       False           13
# Hanna-Barbera      False            1
# HarperCollins      False            3
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           14
# J. K. Rowling      False            1
# J. R. R. Tolkien   False            1
# Marvel Comics      False          330
#                    True            11
# Microsoft          False            1
# NBC - Heroes       False           16
#                    True             2
# Rebellion          False            1
# Shueisha           False            4
# Sony Pictures      False            1
# South Park         False            1
# Star Trek          False            6
# SyFy               False            5
# Team Epic TV       False            5
# Titan Books        False            1
# Universal Studios  False            1
# Unknown            False           13
# Wildstorm          False            3
# Name: Cryokinesis, dtype: int64
# Publisher          Telepathy
# ABC Studios        False          3
#                    True           1
# DC Comics          False        177
#                    True          19
# Dark Horse Comics  False         16
#                    True           2
# George Lucas       False          8
#                    True           5
# Hanna-Barbera      False          1
# HarperCollins      False          3
# IDW Publishing     False          4
# Icon Comics        False          4
# Image Comics       False         11
#                    True           3
# J. K. Rowling      True           1
# J. R. R. Tolkien   False          1
# Marvel Comics      False        284
#                    True          57
# Microsoft          False          1
# NBC - Heroes       False         17
#                    True           1
# Rebellion          False          1
# Shueisha           False          3
#                    True           1
# Sony Pictures      False          1
# South Park         False          1
# Star Trek          False          5
#                    True           1
# SyFy               False          5
# Team Epic TV       False          4
#                    True           1
# Titan Books        False          1
# Universal Studios  False          1
# Unknown            False         13
# Wildstorm          False          3
# Name: Telepathy, dtype: int64
# Publisher          Energy Armor
# ABC Studios        False             4
# DC Comics          False           192
#                    True              4
# Dark Horse Comics  False            18
# George Lucas       False            13
# Hanna-Barbera      False             1
# HarperCollins      False             3
# IDW Publishing     False             4
# Icon Comics        False             4
# Image Comics       False            14
# J. K. Rowling      False             1
# J. R. R. Tolkien   False             1
# Marvel Comics      False           337
#                    True              4
# Microsoft          False             1
# NBC - Heroes       False            18
# Rebellion          False             1
# Shueisha           False             4
# Sony Pictures      False             1
# South Park         False             1
# Star Trek          False             6
# SyFy               False             5
# Team Epic TV       False             5
# Titan Books        False             1
# Universal Studios  False             1
# Unknown            False            13
# Wildstorm          False             3
# Name: Energy Armor, dtype: int64
# Publisher          Energy Blasts
# ABC Studios        False              4
# DC Comics          False            153
#                    True              43
# Dark Horse Comics  False             17
#                    True               1
# George Lucas       False              9
#                    True               4
# Hanna-Barbera      True               1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             10
#                    True               4
# J. K. Rowling      True               1
# J. R. R. Tolkien   True               1
# Marvel Comics      False            254
#                    True              87
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              2
#                    True               2
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              4
#                    True               1
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             11
#                    True               2
# Wildstorm          False              2
#                    True               1
# Name: Energy Blasts, dtype: int64
# Publisher          Duplication
# ABC Studios        False            4
# DC Comics          False          187
#                    True             9
# Dark Horse Comics  False           18
# George Lucas       False           13
# Hanna-Barbera      False            1
# HarperCollins      False            3
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           14
# J. K. Rowling      False            1
# J. R. R. Tolkien   False            1
# Marvel Comics      False          335
#                    True             6
# Microsoft          False            1
# NBC - Heroes       False           18
# Rebellion          False            1
# Shueisha           False            2
#                    True             2
# Sony Pictures      False            1
# South Park         False            1
# Star Trek          False            6
# SyFy               False            5
# Team Epic TV       False            5
# Titan Books        False            1
# Universal Studios  False            1
# Unknown            False           13
# Wildstorm          False            3
# Name: Duplication, dtype: int64
# Publisher          Size Changing
# ABC Studios        False              4
# DC Comics          False            175
#                    True              21
# Dark Horse Comics  False             16
#                    True               2
# George Lucas       False             13
# Hanna-Barbera      False              1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             14
# J. K. Rowling      False              1
# J. R. R. Tolkien   True               1
# Marvel Comics      False            310
#                    True              31
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              4
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              5
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             13
# Wildstorm          False              3
# Name: Size Changing, dtype: int64
# Publisher          Density Control
# ABC Studios        False                4
# DC Comics          False              186
#                    True                10
# Dark Horse Comics  False               17
#                    True                 1
# George Lucas       False               13
# Hanna-Barbera      False                1
# HarperCollins      False                3
# IDW Publishing     False                4
# Icon Comics        False                4
# Image Comics       False               14
# J. K. Rowling      False                1
# J. R. R. Tolkien   False                1
# Marvel Comics      False              337
#                    True                 4
# Microsoft          False                1
# NBC - Heroes       False               18
# Rebellion          False                1
# Shueisha           False                4
# Sony Pictures      False                1
# South Park         False                1
# Star Trek          False                6
# SyFy               False                5
# Team Epic TV       False                5
# Titan Books        False                1
# Universal Studios  False                1
# Unknown            False               13
# Wildstorm          False                3
# Name: Density Control, dtype: int64
# Publisher          Stamina
# ABC Studios        False        4
# DC Comics          False      106
#                    True        90
# Dark Horse Comics  True        11
#                    False        7
# George Lucas       True         7
#                    False        6
# Hanna-Barbera      True         1
# HarperCollins      False        3
# IDW Publishing     True         4
# Icon Comics        True         4
# Image Comics       False        9
#                    True         5
# J. K. Rowling      True         1
# J. R. R. Tolkien   True         1
# Marvel Comics      False      191
#                    True       150
# Microsoft          True         1
# NBC - Heroes       False       18
# Rebellion          True         1
# Shueisha           True         4
# Sony Pictures      True         1
# South Park         False        1
# Star Trek          False        4
#                    True         2
# SyFy               False        5
# Team Epic TV       False        4
#                    True         1
# Titan Books        True         1
# Universal Studios  False        1
# Unknown            True         8
#                    False        5
# Wildstorm          False        2
#                    True         1
# Name: Stamina, dtype: int64
# Publisher          Astral Travel
# ABC Studios        False              4
# DC Comics          False            195
#                    True               1
# Dark Horse Comics  False             18
# George Lucas       False             13
# Hanna-Barbera      False              1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             14
# J. K. Rowling      False              1
# J. R. R. Tolkien   False              1
# Marvel Comics      False            338
#                    True               3
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              4
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              5
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             13
# Wildstorm          False              3
# Name: Astral Travel, dtype: int64
# Publisher          Audio Control
# ABC Studios        False              4
# DC Comics          False            193
#                    True               3
# Dark Horse Comics  False             18
# George Lucas       False             13
# Hanna-Barbera      False              1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             14
# J. K. Rowling      False              1
# J. R. R. Tolkien   False              1
# Marvel Comics      False            336
#                    True               5
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              4
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              5
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             13
# Wildstorm          False              3
# Name: Audio Control, dtype: int64
# Publisher          Dexterity
# ABC Studios        False          4
# DC Comics          False        194
#                    True           2
# Dark Horse Comics  False         18
# George Lucas       False         13
# Hanna-Barbera      False          1
# HarperCollins      False          3
# IDW Publishing     False          4
# Icon Comics        False          4
# Image Comics       False         13
#                    True           1
# J. K. Rowling      False          1
# J. R. R. Tolkien   False          1
# Marvel Comics      False        338
#                    True           3
# Microsoft          False          1
# NBC - Heroes       False         18
# Rebellion          False          1
# Shueisha           False          4
# Sony Pictures      False          1
# South Park         False          1
# Star Trek          False          6
# SyFy               False          5
# Team Epic TV       False          5
# Titan Books        False          1
# Universal Studios  False          1
# Unknown            False         13
# Wildstorm          False          3
# Name: Dexterity, dtype: int64
# Publisher          Omnitrix
# ABC Studios        False         4
# DC Comics          False       195
#                    True          1
# Dark Horse Comics  False        18
# George Lucas       False        13
# Hanna-Barbera      False         1
# HarperCollins      False         3
# IDW Publishing     False         4
# Icon Comics        False         4
# Image Comics       False        14
# J. K. Rowling      False         1
# J. R. R. Tolkien   False         1
# Marvel Comics      False       341
# Microsoft          False         1
# NBC - Heroes       False        18
# Rebellion          False         1
# Shueisha           False         4
# Sony Pictures      False         1
# South Park         False         1
# Star Trek          False         6
# SyFy               False         5
# Team Epic TV       False         5
# Titan Books        False         1
# Universal Studios  False         1
# Unknown            False        13
# Wildstorm          False         3
# Name: Omnitrix, dtype: int64
# Publisher          Super Speed
# ABC Studios        False            3
#                    True             1
# DC Comics          False          117
#                    True            79
# Dark Horse Comics  False           10
#                    True             8
# George Lucas       False            9
#                    True             4
# Hanna-Barbera      False            1
# HarperCollins      True             2
#                    False            1
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           10
#                    True             4
# J. K. Rowling      False            1
# J. R. R. Tolkien   True             1
# Marvel Comics      False          204
#                    True           137
# Microsoft          True             1
# NBC - Heroes       False           18
# Rebellion          False            1
# Shueisha           True             4
# Sony Pictures      True             1
# South Park         True             1
# Star Trek          False            5
#                    True             1
# SyFy               False            4
#                    True             1
# Team Epic TV       False            4
#                    True             1
# Titan Books        False            1
# Universal Studios  False            1
# Unknown            False           10
#                    True             3
# Wildstorm          True             2
#                    False            1
# Name: Super Speed, dtype: int64
# Publisher          Possession
# ABC Studios        False           4
# DC Comics          False         194
#                    True            2
# Dark Horse Comics  False          18
# George Lucas       False          13
# Hanna-Barbera      False           1
# HarperCollins      False           3
# IDW Publishing     False           4
# Icon Comics        False           4
# Image Comics       False          13
#                    True            1
# J. K. Rowling      False           1
# J. R. R. Tolkien   False           1
# Marvel Comics      False         337
#                    True            4
# Microsoft          False           1
# NBC - Heroes       False          18
# Rebellion          False           1
# Shueisha           False           4
# Sony Pictures      False           1
# South Park         False           1
# Star Trek          False           6
# SyFy               False           5
# Team Epic TV       False           5
# Titan Books        False           1
# Universal Studios  False           1
# Unknown            False          13
# Wildstorm          False           3
# Name: Possession, dtype: int64
# Publisher          Animal Oriented Powers
# ABC Studios        False                       4
# DC Comics          False                     185
#                    True                       11
# Dark Horse Comics  False                      18
# George Lucas       False                      13
# Hanna-Barbera      False                       1
# HarperCollins      False                       3
# IDW Publishing     False                       4
# Icon Comics        False                       4
# Image Comics       False                      14
# J. K. Rowling      False                       1
# J. R. R. Tolkien   False                       1
# Marvel Comics      False                     311
#                    True                       30
# Microsoft          False                       1
# NBC - Heroes       False                      18
# Rebellion          False                       1
# Shueisha           False                       4
# Sony Pictures      False                       1
# South Park         False                       1
# Star Trek          False                       6
# SyFy               False                       5
# Team Epic TV       False                       5
# Titan Books        False                       1
# Universal Studios  False                       1
# Unknown            False                      13
# Wildstorm          False                       3
# Name: Animal Oriented Powers, dtype: int64
# Publisher          Weapon-based Powers
# ABC Studios        False                    4
# DC Comics          False                  176
#                    True                    20
# Dark Horse Comics  False                   18
# George Lucas       False                   12
#                    True                     1
# Hanna-Barbera      False                    1
# HarperCollins      False                    3
# IDW Publishing     False                    4
# Icon Comics        False                    2
#                    True                     2
# Image Comics       False                   14
# J. K. Rowling      False                    1
# J. R. R. Tolkien   False                    1
# Marvel Comics      False                  307
#                    True                    34
# Microsoft          True                     1
# NBC - Heroes       False                   18
# Rebellion          True                     1
# Shueisha           False                    4
# Sony Pictures      False                    1
# South Park         False                    1
# Star Trek          False                    6
# SyFy               False                    5
# Team Epic TV       False                    4
#                    True                     1
# Titan Books        False                    1
# Universal Studios  False                    1
# Unknown            False                   11
#                    True                     2
# Wildstorm          False                    3
# Name: Weapon-based Powers, dtype: int64
# Publisher          Electrokinesis
# ABC Studios        False               4
# DC Comics          False             188
#                    True                8
# Dark Horse Comics  False              18
# George Lucas       False              11
#                    True                2
# Hanna-Barbera      False               1
# HarperCollins      False               2
#                    True                1
# IDW Publishing     False               4
# Icon Comics        False               4
# Image Comics       False              14
# J. K. Rowling      False               1
# J. R. R. Tolkien   False               1
# Marvel Comics      False             334
#                    True                7
# Microsoft          False               1
# NBC - Heroes       False              17
#                    True                1
# Rebellion          False               1
# Shueisha           False               3
#                    True                1
# Sony Pictures      False               1
# South Park         False               1
# Star Trek          False               6
# SyFy               False               5
# Team Epic TV       False               5
# Titan Books        False               1
# Universal Studios  False               1
# Unknown            False              13
# Wildstorm          False               3
# Name: Electrokinesis, dtype: int64
# Publisher          Darkforce Manipulation
# ABC Studios        False                       4
# DC Comics          False                     193
#                    True                        3
# Dark Horse Comics  False                      18
# George Lucas       False                      12
#                    True                        1
# Hanna-Barbera      False                       1
# HarperCollins      False                       3
# IDW Publishing     False                       4
# Icon Comics        False                       4
# Image Comics       False                      14
# J. K. Rowling      False                       1
# J. R. R. Tolkien   True                        1
# Marvel Comics      False                     337
#                    True                        4
# Microsoft          False                       1
# NBC - Heroes       False                      18
# Rebellion          False                       1
# Shueisha           False                       4
# Sony Pictures      False                       1
# South Park         False                       1
# Star Trek          False                       6
# SyFy               False                       5
# Team Epic TV       False                       5
# Titan Books        False                       1
# Universal Studios  False                       1
# Unknown            False                      13
# Wildstorm          False                       3
# Name: Darkforce Manipulation, dtype: int64
# Publisher          Death Touch
# ABC Studios        False            4
# DC Comics          False          193
#                    True             3
# Dark Horse Comics  False           18
# George Lucas       False           13
# Hanna-Barbera      False            1
# HarperCollins      False            3
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           14
# J. K. Rowling      False            1
# J. R. R. Tolkien   False            1
# Marvel Comics      False          337
#                    True             4
# Microsoft          False            1
# NBC - Heroes       False           18
# Rebellion          False            1
# Shueisha           False            4
# Sony Pictures      False            1
# ...
# J. K. Rowling      False                    1
# J. R. R. Tolkien   False                    1
# Marvel Comics      False                  341
# Microsoft          False                    1
# NBC - Heroes       False                   18
# Rebellion          False                    1
# Shueisha           False                    4
# Sony Pictures      False                    1
# South Park         False                    1
# Star Trek          False                    6
# SyFy               False                    5
# Team Epic TV       False                    5
# Titan Books        False                    1
# Universal Studios  False                    1
# Unknown            False                   13
# Wildstorm          False                    3
# Name: Qwardian Power Ring, dtype: int64
# Publisher          Weather Control
# ABC Studios        False                4
# DC Comics          False              194
#                    True                 2
# Dark Horse Comics  False               18
# George Lucas       False               13
# Hanna-Barbera      False                1
# HarperCollins      False                3
# IDW Publishing     False                4
# Icon Comics        False                4
# Image Comics       False               14
# J. K. Rowling      False                1
# J. R. R. Tolkien   True                 1
# Marvel Comics      False              338
#                    True                 3
# Microsoft          False                1
# NBC - Heroes       False               18
# Rebellion          False                1
# Shueisha           False                3
#                    True                 1
# Sony Pictures      False                1
# South Park         False                1
# Star Trek          False                6
# SyFy               False                5
# Team Epic TV       False                5
# Titan Books        False                1
# Universal Studios  False                1
# Unknown            False               13
# Wildstorm          False                3
# Name: Weather Control, dtype: int64
# Publisher          Vision - X-Ray
# ABC Studios        False               4
# DC Comics          False             177
#                    True               19
# Dark Horse Comics  False              17
#                    True                1
# George Lucas       False              13
# Hanna-Barbera      False               1
# HarperCollins      False               3
# IDW Publishing     False               4
# Icon Comics        False               4
# Image Comics       False              14
# J. K. Rowling      False               1
# J. R. R. Tolkien   False               1
# Marvel Comics      False             336
#                    True                5
# Microsoft          False               1
# NBC - Heroes       False              18
# Rebellion          False               1
# Shueisha           False               4
# Sony Pictures      False               1
# South Park         False               1
# Star Trek          False               6
# SyFy               False               5
# Team Epic TV       False               5
# Titan Books        False               1
# Universal Studios  False               1
# Unknown            False              13
# Wildstorm          False               3
# Name: Vision - X-Ray, dtype: int64
# Publisher          Vision - Thermal
# ABC Studios        False                 4
# DC Comics          False               188
#                    True                  8
# Dark Horse Comics  False                12
#                    True                  6
# George Lucas       False                13
# Hanna-Barbera      False                 1
# HarperCollins      False                 3
# IDW Publishing     False                 4
# Icon Comics        False                 4
# Image Comics       False                14
# J. K. Rowling      False                 1
# J. R. R. Tolkien   False                 1
# Marvel Comics      False               331
#                    True                 10
# Microsoft          False                 1
# NBC - Heroes       False                18
# Rebellion          False                 1
# Shueisha           False                 4
# Sony Pictures      False                 1
# South Park         False                 1
# Star Trek          False                 6
# SyFy               False                 5
# Team Epic TV       False                 5
# Titan Books        False                 1
# Universal Studios  False                 1
# Unknown            False                13
# Wildstorm          False                 2
#                    True                  1
# Name: Vision - Thermal, dtype: int64
# Publisher          Web Creation
# ABC Studios        False             4
# DC Comics          False           196
# Dark Horse Comics  False            18
# George Lucas       False            13
# Hanna-Barbera      False             1
# HarperCollins      False             3
# IDW Publishing     False             4
# Icon Comics        False             4
# Image Comics       False            14
# J. K. Rowling      False             1
# J. R. R. Tolkien   False             1
# Marvel Comics      False           325
#                    True             16
# Microsoft          False             1
# NBC - Heroes       False            18
# Rebellion          False             1
# Shueisha           False             4
# Sony Pictures      False             1
# South Park         False             1
# Star Trek          False             6
# SyFy               False             5
# Team Epic TV       False             5
# Titan Books        False             1
# Universal Studios  False             1
# Unknown            False            13
# Wildstorm          False             3
# Name: Web Creation, dtype: int64
# Publisher          Reality Warping
# ABC Studios        False                4
# DC Comics          False              193
#                    True                 3
# Dark Horse Comics  False               18
# George Lucas       False               13
# Hanna-Barbera      False                1
# HarperCollins      False                3
# IDW Publishing     False                4
# Icon Comics        False                4
# Image Comics       False               13
#                    True                 1
# J. K. Rowling      True                 1
# J. R. R. Tolkien   False                1
# Marvel Comics      False              333
#                    True                 8
# Microsoft          False                1
# NBC - Heroes       False               18
# Rebellion          False                1
# Shueisha           False                4
# Sony Pictures      False                1
# South Park         False                1
# Star Trek          False                5
#                    True                 1
# SyFy               False                5
# Team Epic TV       False                5
# Titan Books        False                1
# Universal Studios  False                1
# Unknown            False               13
# Wildstorm          False                3
# Name: Reality Warping, dtype: int64
# Publisher          Odin Force
# ABC Studios        False           4
# DC Comics          False         196
# Dark Horse Comics  False          18
# George Lucas       False          13
# Hanna-Barbera      False           1
# HarperCollins      False           3
# IDW Publishing     False           4
# Icon Comics        False           4
# Image Comics       False          14
# J. K. Rowling      False           1
# J. R. R. Tolkien   False           1
# Marvel Comics      False         339
#                    True            2
# Microsoft          False           1
# NBC - Heroes       False          18
# Rebellion          False           1
# Shueisha           False           4
# Sony Pictures      False           1
# South Park         False           1
# Star Trek          False           6
# SyFy               False           5
# Team Epic TV       False           5
# Titan Books        False           1
# Universal Studios  False           1
# Unknown            False          13
# Wildstorm          False           3
# Name: Odin Force, dtype: int64
# Publisher          Symbiote Costume
# ABC Studios        False                 4
# DC Comics          False               195
#                    True                  1
# Dark Horse Comics  False                18
# George Lucas       False                13
# Hanna-Barbera      False                 1
# HarperCollins      False                 3
# IDW Publishing     False                 4
# Icon Comics        False                 4
# Image Comics       False                13
#                    True                  1
# J. K. Rowling      False                 1
# J. R. R. Tolkien   False                 1
# Marvel Comics      False               333
#                    True                  8
# Microsoft          False                 1
# NBC - Heroes       False                18
# Rebellion          False                 1
# Shueisha           False                 4
# Sony Pictures      False                 1
# South Park         False                 1
# Star Trek          False                 6
# SyFy               False                 5
# Team Epic TV       False                 5
# Titan Books        False                 1
# Universal Studios  False                 1
# Unknown            False                13
# Wildstorm          False                 3
# Name: Symbiote Costume, dtype: int64
# Publisher          Speed Force
# ABC Studios        False            4
# DC Comics          False          195
#                    True             1
# Dark Horse Comics  False           18
# George Lucas       False           13
# Hanna-Barbera      False            1
# HarperCollins      False            3
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           14
# J. K. Rowling      False            1
# J. R. R. Tolkien   False            1
# Marvel Comics      False          341
# Microsoft          False            1
# NBC - Heroes       False           18
# Rebellion          False            1
# Shueisha           False            4
# Sony Pictures      False            1
# South Park         False            1
# Star Trek          False            6
# SyFy               False            5
# Team Epic TV       False            5
# Titan Books        False            1
# Universal Studios  False            1
# Unknown            False           13
# Wildstorm          False            3
# Name: Speed Force, dtype: int64
# Publisher          Phoenix Force
# ABC Studios        False              4
# DC Comics          False            196
# Dark Horse Comics  False             18
# George Lucas       False             13
# Hanna-Barbera      False              1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             14
# J. K. Rowling      False              1
# J. R. R. Tolkien   False              1
# Marvel Comics      False            340
#                    True               1
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              4
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              5
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             13
# Wildstorm          False              3
# Name: Phoenix Force, dtype: int64
# Publisher          Molecular Dissipation
# ABC Studios        False                      4
# DC Comics          False                    195
#                    True                       1
# Dark Horse Comics  False                     18
# George Lucas       False                     13
# Hanna-Barbera      False                      1
# HarperCollins      False                      3
# IDW Publishing     False                      4
# Icon Comics        False                      4
# Image Comics       False                     14
# J. K. Rowling      False                      1
# J. R. R. Tolkien   False                      1
# Marvel Comics      False                    341
# Microsoft          False                      1
# NBC - Heroes       False                     18
# Rebellion          False                      1
# Shueisha           False                      4
# Sony Pictures      False                      1
# South Park         False                      1
# Star Trek          False                      6
# SyFy               False                      5
# Team Epic TV       False                      5
# Titan Books        False                      1
# Universal Studios  False                      1
# Unknown            False                     13
# Wildstorm          False                      3
# Name: Molecular Dissipation, dtype: int64
# Publisher          Vision - Cryo
# ABC Studios        False              4
# DC Comics          False            195
#                    True               1
# Dark Horse Comics  False             18
# George Lucas       False             13
# Hanna-Barbera      False              1
# HarperCollins      False              3
# IDW Publishing     False              4
# Icon Comics        False              4
# Image Comics       False             14
# J. K. Rowling      False              1
# J. R. R. Tolkien   False              1
# Marvel Comics      False            341
# Microsoft          False              1
# NBC - Heroes       False             18
# Rebellion          False              1
# Shueisha           False              4
# Sony Pictures      False              1
# South Park         False              1
# Star Trek          False              6
# SyFy               False              5
# Team Epic TV       False              5
# Titan Books        False              1
# Universal Studios  False              1
# Unknown            False             13
# Wildstorm          False              3
# Name: Vision - Cryo, dtype: int64
# Publisher          Omnipresent
# ABC Studios        False            4
# DC Comics          False          196
# Dark Horse Comics  False           18
# George Lucas       False           13
# Hanna-Barbera      False            1
# HarperCollins      False            3
# IDW Publishing     False            4
# Icon Comics        False            4
# Image Comics       False           13
#                    True             1
# J. K. Rowling      False            1
# J. R. R. Tolkien   False            1
# Marvel Comics      False          340
#                    True             1
# Microsoft          False            1
# NBC - Heroes       False           18
# Rebellion          False            1
# Shueisha           False            4
# Sony Pictures      False            1
# South Park         False            1
# Star Trek          False            6
# SyFy               False            5
# Team Epic TV       False            5
# Titan Books        False            1
# Universal Studios  False            1
# Unknown            False           13
# Wildstorm          False            3
# Name: Omnipresent, dtype: int64
# Publisher          Omniscient
# ABC Studios        False           4
# DC Comics          False         196
# Dark Horse Comics  False          18
# George Lucas       False          13
# Hanna-Barbera      False           1
# HarperCollins      False           3
# IDW Publishing     False           4
# Icon Comics        False           4
# Image Comics       False          13
#                    True            1
# J. K. Rowling      False           1
# J. R. R. Tolkien   False           1
# Marvel Comics      False         340
#                    True            1
# Microsoft          False           1
# NBC - Heroes       False          18
# Rebellion          False           1
# Shueisha           False           4
# Sony Pictures      False           1
# South Park         False           1
# Star Trek          False           6
# SyFy               False           5
# Team Epic TV       False           5
# Titan Books        False           1
# Universal Studios  False           1
# Unknown            False          13
# Wildstorm          False           3
# Name: Omniscient, dtype: int64

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == [
    "DC Comics",
    "Marvel Comics",
    "Superpower Name",
]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [147], line 7
#       4 assert type(question_3_df) == pd.DataFrame
#       6 # Checking the shape
# ----> 7 assert question_3_df.shape == (167, 3)
#       9 # Checking the column names
#      10 assert sorted(list(question_3_df.columns)) == [
#      11     "DC Comics",
#      12     "Marvel Comics",
#      13     "Superpower Name",
#      14 ]
#
# AssertionError:

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(
    by="Marvel Comics", ascending=False
)[:5]
marvel_most_common

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"], height=marvel_most_common["Marvel Comics"]
)
ax2.bar(x=dc_most_common["Superpower Name"], height=dc_most_common["DC Comics"])

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
None
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
